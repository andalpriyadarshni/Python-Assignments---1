# %%
# number guessing game using while loop and control statements

# %%
import random
secret_number = random.randint(1,10)

# %%
secret_number = 5
attempts = 0
max_attempts = 4

while attempts < max_attempts:
    guess = int(input("Guess the number between 1 and 10: "))
    attempts +=1


    if guess > 10 or guess < 1:
        print("Your guess is out of range! Try again.")
        continue

    if guess > secret_number:
        print("Your guess is too high.")
    elif guess < secret_number:
        print("Your guess is too low.")
    else:
        print("Congratulations! You guessed it right!")
        break
else:
    print("Sorry, you've used all attempts. Better luck next time!")

print("Game Over.")
# Out:
# Guess the number between 1 and 10: 11
# Your guess is out of range! Try again.
# Guess the number between 1 and 10: 10
# Your guess is too high.
# Guess the number between 1 and 10: 4
# Your guess is too low.
# Guess the number between 1 and 10: 5
# Congratulations! You guessed it right!
# Game Over.

# %%
# calculate BMI

# %%
def calculate_bmi():
  weight= float(input("enter your weight in kg:" ))
  height=float(input("enter your height in meters:" ))

  bmi = weight/(height**2)
  print("your BMI is:" ,round(bmi,2))

calculate_bmi()
# Out:
# enter your weight in kg:58
# enter your height in meters:1.62
# your BMI is: 22.1

# %%
# multiplication of 10

# %%
x = int(input("enter a number for which you want the multiplication Table:" ))

for i in range(1,11):
     print(f"{x} x {i} = {x*i}")
# Out:
# enter a number for which you want the multiplication Table:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

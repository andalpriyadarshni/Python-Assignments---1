# %%
# Conmcatenate 'Hello' + 'Name'
# greeting message 'welcome to Python programming'

# %%
'Hello' + " " 'Andal'
# Out:
# 'Hello Andal'

# %%
'Hello Andal,' + " " + 'welcome to Python programming'
# Out:
# 'Hello Andal, welcome to Python programming'

# %%
s = 'Hello Andal, welcome to Python programming'

# %%
# print first character of the string
# print last character of the string

# %%
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# 'g'

# %%
# print the first 5 character of the string
# print last 11 character of the string

# %%
s[0:5:1]
# Out:
# 'Hello'

# %%
s[31:]
# Out:
# 'programming'

# %%
# string in reverse
# print the word python

# %%
s[:-43:-1]
# Out:
# 'gnimmargorp nohtyP ot emoclew ,ladnA olleH'

# %%
s[24:30:1]
# Out:
# 'Python'

# %%
strM = 'Python beginner tutorial'

# %%
# convert into upper case
# convert into lower case
# use capitalize

# %%
strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
strM.lower()
# Out:
# 'python beginner tutorial'

# %%
strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
# count total occurrences of 't'
# replace pyhton with 'Machine Learning'

# %%
strM.count('t')
# Out:
# 3

# %%
strM.replace('Python','Machine Learning')
# Out:
# 'Machine Learning beginner tutorial'

# %%
# tuple
# create tuple 1 --->(10,20,30) and tuple 2 ---->(40,50,60)

# %%
tup  = (10,20,30)

# %%
_tup = (40,50,60)

# %%
# concatenate both tuple
# store it in t_combine

# %%
tup + _tup
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t_combine = tup + _tup

# %%
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
# repeat t_combine 3 times

# %%
(t_combine)*3
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
# Acess 3rd element
# Acess last three element
# Acess first three element

# %%
t_combine[2]
# Out:
# 30

# %%
t_combine[0:3]
# Out:
# (10, 20, 30)

# %%
t_combine[-3:]
# Out:
# (40, 50, 60)
